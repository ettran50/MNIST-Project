# %%
# !pip install medmnist
# !pip install -U libauc
# Out:
# Collecting medmnist
#   Downloading medmnist-3.0.1-py3-none-any.whl (25 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from medmnist) (1.25.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from medmnist) (2.0.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from medmnist) (1.2.2)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from medmnist) (0.19.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from medmnist) (4.66.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from medmnist) (9.4.0)
# Collecting fire (from medmnist)
#   Downloading fire-0.6.0.tar.gz (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.4/88.4 kB 1.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from medmnist) (2.2.1+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from medmnist) (0.17.1+cu121)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from fire->medmnist) (1.16.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/dist-packages (from fire->medmnist) (2.4.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->medmnist) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->medmnist) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->medmnist) (2024.1)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->medmnist) (1.11.4)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image->medmnist) (3.3)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->medmnist) (2.31.6)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image->medmnist) (2024.4.24)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->medmnist) (1.6.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image->medmnist) (24.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->medmnist) (1.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->medmnist) (3.5.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->medmnist) (3.14.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch->medmnist) (4.11.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->medmnist) (1.12)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->medmnist) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->medmnist) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch->medmnist)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch->medmnist)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch->medmnist)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch->medmnist)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch->medmnist)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch->medmnist)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch->medmnist)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch->medmnist)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch->medmnist)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.19.3 (from torch->medmnist)
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch->medmnist)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch->medmnist) (2.2.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch->medmnist)
#   Using cached nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->medmnist) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->medmnist) (1.3.0)
# Building wheels for collected packages: fire
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.6.0-py2.py3-none-any.whl size=117029 sha256=c28f3a81d4af6a26a38cd5cdb58788282b52dea70bf5e70b66241b88c122b3e2
#   Stored in directory: /root/.cache/pip/wheels/d6/6d/5d/5b73fa0f46d01a793713f8859201361e9e581ced8c75e5c6a3
# Successfully built fire
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, fire, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, medmnist
# Successfully installed fire-0.6.0 medmnist-3.0.1 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.1.105
# Collecting libauc
#   Downloading libauc-1.3.3-py3-none-any.whl (120 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.6/120.6 kB 1.6 MB/s eta 0:00:00
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from libauc) (2.2.1+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from libauc) (0.17.1+cu121)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from libauc) (1.25.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from libauc) (4.66.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from libauc) (1.11.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from libauc) (2.0.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from libauc) (9.4.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from libauc) (1.2.2)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from libauc) (4.8.0.76)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->libauc) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->libauc) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->libauc) (2024.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->libauc) (1.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->libauc) (3.5.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->libauc) (3.14.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch->libauc) (4.11.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->libauc) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->libauc) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->libauc) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->libauc) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->libauc) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->libauc) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->libauc) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch->libauc) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch->libauc) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch->libauc) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch->libauc) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch->libauc) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch->libauc) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.10/dist-packages (from torch->libauc) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->libauc) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch->libauc) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->libauc) (12.4.127)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->libauc) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->libauc) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->libauc) (1.3.0)
# Installing collected packages: libauc
# Successfully installed libauc-1.3.3

# %%
# !nvidia-smi
# Out:
# Tue Apr 30 20:20:27 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   46C    P8              10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
import torch
import numpy as np
import torchvision
from torchvision import transforms
from libauc.models import resnet18 as ResNet18
from libauc.losses import AUCMLoss
from torch.nn import BCELoss
import torch.nn as nn
from torch.optim import SGD
from libauc.optimizers import PESG
import medmnist
from medmnist import INFO, Evaluator
import os
from sklearn import metrics
from sklearn.metrics import roc_auc_score
from PIL import Image
from torch.utils.data import Dataset
from torchvision import transforms
from libauc.metrics import auc_roc_score

torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
torch.manual_seed(2024)
np.random.seed(2024)

# Check GPU availability
torch.cuda.is_available()

# Check GPU device name
import tensorflow as tf
tf.test.gpu_device_name()

# Additional imports
import torch.utils.data as data

# %%
# HyperParameters
SEED = 123
BATCH_SIZE = 128
imratio = 0.1 # for demo
total_epochs = 100
decay_epochs = [50, 75]

lr = 0.1
margin = 1.0
epoch_decay = 0.003 # refers gamma in the paper
weight_decay = 0.0001

# oversampling minority class, you can tune it in (0, 0.5]
# e.g., sampling_rate=0.2 is that num of positive samples in mini-batch is sampling_rate*batch_size=13
sampling_rate = 0.2

# %%
#data_flag = 'pathmnist'
data_flag = 'breastmnist'
download = True

info = INFO[data_flag]
task = info['task']
n_channels = info['n_channels']
n_classes = len(info['label'])

DataClass = getattr(medmnist, info['python_class'])

# %%
# preprocessing
data_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[.5], std=[.5])
])

# load the data
train_dataset = DataClass(split='train', transform=data_transform, download=download)
test_dataset = DataClass(split='test', transform=data_transform, download=download)

pil_dataset = DataClass(split='train', download=download)

# encapsulate data into dataloader form
train_loader = data.DataLoader(dataset=train_dataset, batch_size=BATCH_SIZE, shuffle=False)
train_loader_at_eval = data.DataLoader(dataset=train_dataset, batch_size=2*BATCH_SIZE, shuffle=False)
test_loader = data.DataLoader(dataset=test_dataset, batch_size=2*BATCH_SIZE, shuffle=False)
# Out:
# Downloading https://zenodo.org/records/10519652/files/breastmnist.npz?download=1 to /root/.medmnist/breastmnist.npz
# 100%|██████████| 559580/559580 [00:00<00:00, 1146790.34it/s]
# Using downloaded and verified file: /root/.medmnist/breastmnist.npz
# Using downloaded and verified file: /root/.medmnist/breastmnist.npz

# %%
print(train_dataset)
print("===================")
print(test_dataset)
# Out:
# Dataset BreastMNIST of size 28 (breastmnist)
#     Number of datapoints: 546
#     Root location: /root/.medmnist
#     Split: train
#     Task: binary-class
#     Number of channels: 1
#     Meaning of labels: {'0': 'malignant', '1': 'normal, benign'}
#     Number of samples: {'train': 546, 'val': 78, 'test': 156}
#     Description: The BreastMNIST is based on a dataset of 780 breast ultrasound images. It is categorized into 3 classes: normal, benign, and malignant. As we use low-resolution images, we simplify the task into binary classification by combining normal and benign as positive and classifying them against malignant as negative. We split the source dataset with a ratio of 7:1:2 into training, validation and test set. The source images of 1×500×500 are resized into 1×28×28.
#     License: CC BY 4.0
# ===================
# Dataset BreastMNIST of size 28 (breastmnist)
#     Number of datapoints: 156
#     Root location: /root/.medmnist
#     Split: test
#     Task: binary-class
#     Number of channels: 1
#     Meaning of labels: {'0': 'malignant', '1': 'normal, benign'}
#     Number of samples: {'train': 546, 'val': 78, 'test': 156}
#     Description: The BreastMNIST is based on a dataset of 780 breast ultrasound images. It is categorized into 3 classes: normal, benign, and malignant. As we use low-resolution images, we simplify the task into binary classification by combining normal and benign as positive and classifying them against malignant as negative. We split the source dataset with a ratio of 7:1:2 into training, validation and test set. The source images of 1×500×500 are resized into 1×28×28.
#     License: CC BY 4.0

# %%
train_dataset.montage(length=20)
# Out:
# /usr/local/lib/python3.10/dist-packages/medmnist/utils.py:32: FutureWarning: `multichannel` is a deprecated argument name for `montage`. It will be removed in version 1.0. Please use `channel_axis` instead.
#   montage_arr = skimage_montage(sel_img, multichannel=(n_channels == 3))
# <PIL.Image.Image image mode=L size=560x560>

# %%
######### DEFAULT ##############

# You can include sigmoid/l2 activations on model's outputs before computing loss
model = ResNet18(pretrained=True, last_activation=None, num_classes=1)
model.conv1 = nn.Conv2d(n_channels, 64, kernel_size=7, stride=2, padding=3,bias=False)
model = model.cuda()

# You can also pass Loss.a, Loss.b, Loss.alpha to optimizer (for old version users)
loss_fn = AUCMLoss()
optimizer = PESG(model.parameters(),
                 loss_fn=loss_fn,
                 lr=lr,
                 momentum=0.9,
                 margin=margin,
                 epoch_decay=epoch_decay,
                 weight_decay=weight_decay)

# %%
print ('Start Training')
print ('-'*30)

train_log = []
test_log = []
for epoch in range(total_epochs):
     if epoch in decay_epochs:
         optimizer.update_regularizer(decay_factor=10) # decrease learning rate by 10x & update regularizer

     train_loss = []
     model.train()
     for data, targets in train_loader:
         data, targets  = data.cuda(), targets.cuda()
         y_pred = model(data)
         y_pred = torch.sigmoid(y_pred)
         loss = loss_fn(y_pred, targets)
         optimizer.zero_grad()
         loss.backward()
         optimizer.step()
         train_loss.append(loss.item())

     # evaluation on train & test sets
     model.eval()
     train_pred_list = []
     train_true_list = []
     for train_data, train_targets in train_loader_at_eval:
         train_data = train_data.cuda()
         train_pred = model(train_data)
         train_pred_list.append(train_pred.cpu().detach().numpy())
         train_true_list.append(train_targets.numpy())
     train_true = np.concatenate(train_true_list)
     train_pred = np.concatenate(train_pred_list)
     train_auc = auc_roc_score(train_true, train_pred)
     train_loss = np.mean(train_loss)

     test_pred_list = []
     test_true_list = []
     for test_data, test_targets in test_loader:
         test_data = test_data.cuda()
         test_pred = model(test_data)
         test_pred_list.append(test_pred.cpu().detach().numpy())
         test_true_list.append(test_targets.numpy())
     test_true = np.concatenate(test_true_list)
     test_pred = np.concatenate(test_pred_list)
     val_auc =  auc_roc_score(test_true, test_pred)
     model.train()

     # print results
     print("epoch: %s, train_loss: %.4f, train_auc: %.4f, test_auc: %.4f, lr: %.4f"%(epoch, train_loss, train_auc, val_auc, optimizer.lr ))
     train_log.append(train_auc)
     test_log.append(val_auc)
# Out:
# Start Training
# ------------------------------
# epoch: 0, train_loss: 0.1036, train_auc: 0.6798, test_auc: 0.6640, lr: 0.1000
# epoch: 1, train_loss: 0.1514, train_auc: 0.5082, test_auc: 0.5196, lr: 0.1000
# epoch: 2, train_loss: 0.1389, train_auc: 0.4720, test_auc: 0.4768, lr: 0.1000
# epoch: 3, train_loss: 0.1020, train_auc: 0.5428, test_auc: 0.6126, lr: 0.1000
# epoch: 4, train_loss: 0.0569, train_auc: 0.5802, test_auc: 0.6287, lr: 0.1000
# epoch: 5, train_loss: 0.0288, train_auc: 0.5575, test_auc: 0.6646, lr: 0.1000
# epoch: 6, train_loss: 0.0002, train_auc: 0.6543, test_auc: 0.6767, lr: 0.1000
# epoch: 7, train_loss: -0.0064, train_auc: 0.7278, test_auc: 0.6853, lr: 0.1000
# epoch: 8, train_loss: -0.0054, train_auc: 0.8111, test_auc: 0.6944, lr: 0.1000
# epoch: 9, train_loss: -0.0048, train_auc: 0.9273, test_auc: 0.7339, lr: 0.1000
# epoch: 10, train_loss: -0.0038, train_auc: 0.9823, test_auc: 0.7953, lr: 0.1000
# epoch: 11, train_loss: -0.0024, train_auc: 0.9892, test_auc: 0.8033, lr: 0.1000
# epoch: 12, train_loss: -0.0010, train_auc: 0.9886, test_auc: 0.8177, lr: 0.1000
# epoch: 13, train_loss: 0.0003, train_auc: 0.9881, test_auc: 0.8212, lr: 0.1000
# epoch: 14, train_loss: 0.0013, train_auc: 0.9876, test_auc: 0.8252, lr: 0.1000
# epoch: 15, train_loss: 0.0020, train_auc: 0.9872, test_auc: 0.8285, lr: 0.1000
# epoch: 16, train_loss: 0.0024, train_auc: 0.9871, test_auc: 0.8310, lr: 0.1000
# epoch: 17, train_loss: 0.0028, train_auc: 0.9871, test_auc: 0.8317, lr: 0.1000
# epoch: 18, train_loss: 0.0030, train_auc: 0.9873, test_auc: 0.8321, lr: 0.1000
# epoch: 19, train_loss: 0.0032, train_auc: 0.9880, test_auc: 0.8323, lr: 0.1000
# epoch: 20, train_loss: 0.0032, train_auc: 0.9908, test_auc: 0.8279, lr: 0.1000
# epoch: 21, train_loss: 0.0028, train_auc: 0.9865, test_auc: 0.7811, lr: 0.1000
# epoch: 22, train_loss: 0.0039, train_auc: 0.9913, test_auc: 0.8482, lr: 0.1000
# epoch: 23, train_loss: 0.0026, train_auc: 0.9907, test_auc: 0.8461, lr: 0.1000
# epoch: 24, train_loss: 0.0025, train_auc: 0.9907, test_auc: 0.8505, lr: 0.1000
# epoch: 25, train_loss: 0.0025, train_auc: 0.9907, test_auc: 0.8523, lr: 0.1000
# epoch: 26, train_loss: 0.0025, train_auc: 0.9908, test_auc: 0.8532, lr: 0.1000
# epoch: 27, train_loss: 0.0025, train_auc: 0.9908, test_auc: 0.8530, lr: 0.1000
# epoch: 28, train_loss: 0.0025, train_auc: 0.9908, test_auc: 0.8532, lr: 0.1000
# epoch: 29, train_loss: 0.0025, train_auc: 0.9908, test_auc: 0.8534, lr: 0.1000
# epoch: 30, train_loss: 0.0025, train_auc: 0.9908, test_auc: 0.8532, lr: 0.1000
# epoch: 31, train_loss: 0.0025, train_auc: 0.9908, test_auc: 0.8532, lr: 0.1000
# epoch: 32, train_loss: 0.0025, train_auc: 0.9908, test_auc: 0.8525, lr: 0.1000
# epoch: 33, train_loss: 0.0025, train_auc: 0.9908, test_auc: 0.8521, lr: 0.1000
# epoch: 34, train_loss: 0.0025, train_auc: 0.9908, test_auc: 0.8521, lr: 0.1000
# epoch: 35, train_loss: 0.0025, train_auc: 0.9908, test_auc: 0.8519, lr: 0.1000
# epoch: 36, train_loss: 0.0025, train_auc: 0.9908, test_auc: 0.8513, lr: 0.1000
# epoch: 37, train_loss: 0.0025, train_auc: 0.9908, test_auc: 0.8509, lr: 0.1000
# epoch: 38, train_loss: 0.0025, train_auc: 0.9908, test_auc: 0.8507, lr: 0.1000
# epoch: 39, train_loss: 0.0025, train_auc: 0.9908, test_auc: 0.8505, lr: 0.1000
# epoch: 40, train_loss: 0.0025, train_auc: 0.9908, test_auc: 0.8505, lr: 0.1000
# epoch: 41, train_loss: 0.0025, train_auc: 0.9909, test_auc: 0.8505, lr: 0.1000
# epoch: 42, train_loss: 0.0025, train_auc: 0.9909, test_auc: 0.8500, lr: 0.1000
# epoch: 43, train_loss: 0.0025, train_auc: 0.9909, test_auc: 0.8500, lr: 0.1000
# epoch: 44, train_loss: 0.0025, train_auc: 0.9909, test_auc: 0.8500, lr: 0.1000
# epoch: 45, train_loss: 0.0025, train_auc: 0.9909, test_auc: 0.8500, lr: 0.1000
# epoch: 46, train_loss: 0.0025, train_auc: 0.9910, test_auc: 0.8498, lr: 0.1000
# epoch: 47, train_loss: 0.0025, train_auc: 0.9910, test_auc: 0.8496, lr: 0.1000
# epoch: 48, train_loss: 0.0025, train_auc: 0.9910, test_auc: 0.8498, lr: 0.1000
# epoch: 49, train_loss: 0.0025, train_auc: 0.9910, test_auc: 0.8498, lr: 0.1000
# Reducing learning rate to 0.01000 @ T=250!
# Updating regularizer @ T=250!
# epoch: 50, train_loss: 0.0025, train_auc: 0.9909, test_auc: 0.8503, lr: 0.0100
# epoch: 51, train_loss: 0.0025, train_auc: 0.9909, test_auc: 0.8492, lr: 0.0100
# epoch: 52, train_loss: 0.0025, train_auc: 0.9909, test_auc: 0.8482, lr: 0.0100
# epoch: 53, train_loss: 0.0025, train_auc: 0.9908, test_auc: 0.8475, lr: 0.0100
# epoch: 54, train_loss: 0.0025, train_auc: 0.9908, test_auc: 0.8473, lr: 0.0100
# epoch: 55, train_loss: 0.0025, train_auc: 0.9908, test_auc: 0.8471, lr: 0.0100
# epoch: 56, train_loss: 0.0025, train_auc: 0.9908, test_auc: 0.8469, lr: 0.0100
# epoch: 57, train_loss: 0.0025, train_auc: 0.9908, test_auc: 0.8467, lr: 0.0100
# epoch: 58, train_loss: 0.0025, train_auc: 0.9908, test_auc: 0.8467, lr: 0.0100
# epoch: 59, train_loss: 0.0025, train_auc: 0.9908, test_auc: 0.8467, lr: 0.0100
# epoch: 60, train_loss: 0.0025, train_auc: 0.9908, test_auc: 0.8467, lr: 0.0100
# epoch: 61, train_loss: 0.0025, train_auc: 0.9908, test_auc: 0.8467, lr: 0.0100
# epoch: 62, train_loss: 0.0025, train_auc: 0.9908, test_auc: 0.8467, lr: 0.0100
# epoch: 63, train_loss: 0.0025, train_auc: 0.9908, test_auc: 0.8467, lr: 0.0100
# epoch: 64, train_loss: 0.0025, train_auc: 0.9908, test_auc: 0.8467, lr: 0.0100
# epoch: 65, train_loss: 0.0025, train_auc: 0.9908, test_auc: 0.8467, lr: 0.0100
# epoch: 66, train_loss: 0.0025, train_auc: 0.9908, test_auc: 0.8467, lr: 0.0100
# epoch: 67, train_loss: 0.0025, train_auc: 0.9908, test_auc: 0.8467, lr: 0.0100
# epoch: 68, train_loss: 0.0025, train_auc: 0.9908, test_auc: 0.8467, lr: 0.0100
# epoch: 69, train_loss: 0.0025, train_auc: 0.9908, test_auc: 0.8467, lr: 0.0100
# epoch: 70, train_loss: 0.0025, train_auc: 0.9908, test_auc: 0.8467, lr: 0.0100
# epoch: 71, train_loss: 0.0025, train_auc: 0.9908, test_auc: 0.8467, lr: 0.0100
# epoch: 72, train_loss: 0.0025, train_auc: 0.9908, test_auc: 0.8467, lr: 0.0100
# epoch: 73, train_loss: 0.0025, train_auc: 0.9908, test_auc: 0.8467, lr: 0.0100
# epoch: 74, train_loss: 0.0025, train_auc: 0.9908, test_auc: 0.8467, lr: 0.0100
# Reducing learning rate to 0.00100 @ T=375!
# Updating regularizer @ T=375!
# epoch: 75, train_loss: 0.0025, train_auc: 0.9908, test_auc: 0.8467, lr: 0.0010
# epoch: 76, train_loss: 0.0025, train_auc: 0.9908, test_auc: 0.8467, lr: 0.0010
# epoch: 77, train_loss: 0.0025, train_auc: 0.9908, test_auc: 0.8467, lr: 0.0010
# epoch: 78, train_loss: 0.0025, train_auc: 0.9908, test_auc: 0.8467, lr: 0.0010
# epoch: 79, train_loss: 0.0025, train_auc: 0.9908, test_auc: 0.8467, lr: 0.0010
# epoch: 80, train_loss: 0.0025, train_auc: 0.9908, test_auc: 0.8467, lr: 0.0010
# epoch: 81, train_loss: 0.0025, train_auc: 0.9908, test_auc: 0.8467, lr: 0.0010
# epoch: 82, train_loss: 0.0025, train_auc: 0.9908, test_auc: 0.8467, lr: 0.0010
# epoch: 83, train_loss: 0.0025, train_auc: 0.9908, test_auc: 0.8467, lr: 0.0010
# epoch: 84, train_loss: 0.0025, train_auc: 0.9908, test_auc: 0.8467, lr: 0.0010
# epoch: 85, train_loss: 0.0025, train_auc: 0.9908, test_auc: 0.8467, lr: 0.0010
# epoch: 86, train_loss: 0.0025, train_auc: 0.9908, test_auc: 0.8467, lr: 0.0010
# epoch: 87, train_loss: 0.0025, train_auc: 0.9908, test_auc: 0.8467, lr: 0.0010
# epoch: 88, train_loss: 0.0025, train_auc: 0.9908, test_auc: 0.8467, lr: 0.0010
# epoch: 89, train_loss: 0.0025, train_auc: 0.9908, test_auc: 0.8467, lr: 0.0010
# epoch: 90, train_loss: 0.0025, train_auc: 0.9908, test_auc: 0.8467, lr: 0.0010
# epoch: 91, train_loss: 0.0025, train_auc: 0.9908, test_auc: 0.8467, lr: 0.0010
# epoch: 92, train_loss: 0.0025, train_auc: 0.9908, test_auc: 0.8467, lr: 0.0010
# epoch: 93, train_loss: 0.0025, train_auc: 0.9908, test_auc: 0.8467, lr: 0.0010
# epoch: 94, train_loss: 0.0025, train_auc: 0.9908, test_auc: 0.8467, lr: 0.0010
# epoch: 95, train_loss: 0.0025, train_auc: 0.9908, test_auc: 0.8467, lr: 0.0010
# epoch: 96, train_loss: 0.0025, train_auc: 0.9908, test_auc: 0.8467, lr: 0.0010
# epoch: 97, train_loss: 0.0025, train_auc: 0.9908, test_auc: 0.8467, lr: 0.0010
# epoch: 98, train_loss: 0.0025, train_auc: 0.9908, test_auc: 0.8467, lr: 0.0010
# epoch: 99, train_loss: 0.0025, train_auc: 0.9908, test_auc: 0.8467, lr: 0.0010

# %%
torch.save(model, "resnet_breast.pt")

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (9,5)
x=np.arange(len(train_log))
plt.figure()
plt.plot(x, train_log, linestyle='-', label='Train Set', linewidth=3)
plt.plot(x, test_log,  linestyle='-', label='Test Set', linewidth=3)
plt.title('AUCMLoss ',fontsize=25)
plt.legend(fontsize=15)
plt.ylabel('AUROC', fontsize=25)
plt.xlabel('Epoch', fontsize=25)
# Out:
# Text(0.5, 0, 'Epoch')

# %%
del model

# %%
import torch
import numpy as np
import torchvision
from torchvision import transforms
from libauc.models import resnet18 as ResNet18
from libauc.losses import AUCMLoss
from torch.nn import BCELoss
from torch.optim import SGD
from libauc.optimizers import PESG
import medmnist
from medmnist import INFO, Evaluator
import os
from sklearn import metrics
from sklearn.metrics import roc_auc_score
from PIL import Image
from torch.utils.data import Dataset
from torchvision import transforms
from libauc.metrics import auc_roc_score

torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
torch.manual_seed(2024)
np.random.seed(2024)

# Check GPU availability
torch.cuda.is_available()

# Check GPU device name
import tensorflow as tf
tf.test.gpu_device_name()

# Additional imports
import torch.utils.data as data

# %%
data_flag = 'pneumoniamnist'

download = True

info = INFO[data_flag]
task = info['task']
n_channels = info['n_channels']
n_classes = len(info['label'])

DataClass = getattr(medmnist, info['python_class'])

# %%
# preprocessing
data_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[.5], std=[.5])
])

# load the data
train_dataset = DataClass(split='train', transform=data_transform, download=download)
test_dataset = DataClass(split='test', transform=data_transform, download=download)

pil_dataset = DataClass(split='train', download=download)

# encapsulate data into dataloader form
train_loader = data.DataLoader(dataset=train_dataset, batch_size=BATCH_SIZE, shuffle=False)
train_loader_at_eval = data.DataLoader(dataset=train_dataset, batch_size=2*BATCH_SIZE, shuffle=False)
test_loader = data.DataLoader(dataset=test_dataset, batch_size=2*BATCH_SIZE, shuffle=False)
# Out:
# Downloading https://zenodo.org/records/10519652/files/pneumoniamnist.npz?download=1 to /root/.medmnist/pneumoniamnist.npz
# 100%|██████████| 4170669/4170669 [00:00<00:00, 4746780.45it/s]
# Using downloaded and verified file: /root/.medmnist/pneumoniamnist.npz
# Using downloaded and verified file: /root/.medmnist/pneumoniamnist.npz
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-995422747668> in <cell line: 14>()
#      12
#      13 # encapsulate data into dataloader form
# ---> 14 train_loader = data.DataLoader(dataset=train_dataset, batch_size=BATCH_SIZE, shuffle=False)
#      15 train_loader_at_eval = data.DataLoader(dataset=train_dataset, batch_size=2*BATCH_SIZE, shuffle=False)
#      16 test_loader = data.DataLoader(dataset=test_dataset, batch_size=2*BATCH_SIZE, shuffle=False)
#
# AttributeError: 'Tensor' object has no attribute 'DataLoader'

# %%
print(train_dataset)
print("===================")
print(test_dataset)

# %%
train_dataset.montage(length=20)
# Out:
# /usr/local/lib/python3.10/dist-packages/medmnist/utils.py:32: FutureWarning: `multichannel` is a deprecated argument name for `montage`. It will be removed in version 1.0. Please use `channel_axis` instead.
#   montage_arr = skimage_montage(sel_img, multichannel=(n_channels == 3))
# <PIL.Image.Image image mode=L size=560x560>

# %%
######### DEFAULT ##############

# You can include sigmoid/l2 activations on model's outputs before computing loss
model = ResNet18(pretrained=True, last_activation=None, num_classes=1)
model.conv1 = nn.Conv2d(n_channels, 64, kernel_size=7, stride=2, padding=3,bias=False)
model = model.cuda()

# You can also pass Loss.a, Loss.b, Loss.alpha to optimizer (for old version users)
loss_fn = AUCMLoss()
optimizer = PESG(model.parameters(),
                 loss_fn=loss_fn,
                 lr=lr,
                 momentum=0.9,
                 margin=margin,
                 epoch_decay=epoch_decay,
                 weight_decay=weight_decay)

# %%
print ('Start Training')
print ('-'*30)

train_log = []
test_log = []
for epoch in range(20):
     if epoch in decay_epochs:
         optimizer.update_regularizer(decay_factor=10) # decrease learning rate by 10x & update regularizer

     train_loss = []
     model.train()
     for data, targets in train_loader:
         data, targets  = data.cuda(), targets.cuda()
         y_pred = model(data)
         y_pred = torch.sigmoid(y_pred)
         loss = loss_fn(y_pred, targets)
         optimizer.zero_grad()
         loss.backward()
         optimizer.step()
         train_loss.append(loss.item())

     # evaluation on train & test sets
     model.eval()
     train_pred_list = []
     train_true_list = []
     for train_data, train_targets in train_loader_at_eval:
         train_data = train_data.cuda()
         train_pred = model(train_data)
         train_pred_list.append(train_pred.cpu().detach().numpy())
         train_true_list.append(train_targets.numpy())
     train_true = np.concatenate(train_true_list)
     train_pred = np.concatenate(train_pred_list)
     train_auc = auc_roc_score(train_true, train_pred)
     train_loss = np.mean(train_loss)

     test_pred_list = []
     test_true_list = []
     for test_data, test_targets in test_loader:
         test_data = test_data.cuda()
         test_pred = model(test_data)
         test_pred_list.append(test_pred.cpu().detach().numpy())
         test_true_list.append(test_targets.numpy())
     test_true = np.concatenate(test_true_list)
     test_pred = np.concatenate(test_pred_list)
     val_auc =  auc_roc_score(test_true, test_pred)
     model.train()

     # print results
     print("epoch: %s, train_loss: %.4f, train_auc: %.4f, test_auc: %.4f, lr: %.4f"%(epoch, train_loss, train_auc, val_auc, optimizer.lr ))
     train_log.append(train_auc)
     test_log.append(val_auc)
# Out:
# Start Training
# ------------------------------
# epoch: 0, train_loss: 0.1226, train_auc: 0.4893, test_auc: 0.4532, lr: 0.1000
# epoch: 1, train_loss: 0.1668, train_auc: 0.6297, test_auc: 0.6203, lr: 0.1000
# epoch: 2, train_loss: 0.1350, train_auc: 0.6350, test_auc: 0.6652, lr: 0.1000
# epoch: 3, train_loss: 0.1101, train_auc: 0.5751, test_auc: 0.6165, lr: 0.1000
# epoch: 4, train_loss: 0.0733, train_auc: 0.6674, test_auc: 0.7383, lr: 0.1000
# epoch: 5, train_loss: 0.0285, train_auc: 0.7440, test_auc: 0.7843, lr: 0.1000
# epoch: 6, train_loss: -0.0012, train_auc: 0.8126, test_auc: 0.7947, lr: 0.1000
# epoch: 7, train_loss: -0.0093, train_auc: 0.8647, test_auc: 0.8235, lr: 0.1000
# epoch: 8, train_loss: -0.0114, train_auc: 0.9120, test_auc: 0.8596, lr: 0.1000
# epoch: 9, train_loss: -0.0107, train_auc: 0.9538, test_auc: 0.8847, lr: 0.1000
# epoch: 10, train_loss: -0.0075, train_auc: 0.9806, test_auc: 0.8743, lr: 0.1000
# epoch: 11, train_loss: -0.0048, train_auc: 0.9915, test_auc: 0.8782, lr: 0.1000
# epoch: 12, train_loss: -0.0024, train_auc: 0.9934, test_auc: 0.8810, lr: 0.1000
# epoch: 13, train_loss: -0.0008, train_auc: 0.9938, test_auc: 0.8776, lr: 0.1000
# epoch: 14, train_loss: 0.0003, train_auc: 0.9942, test_auc: 0.8697, lr: 0.1000
# epoch: 15, train_loss: 0.0009, train_auc: 0.9944, test_auc: 0.8557, lr: 0.1000
# epoch: 16, train_loss: 0.0013, train_auc: 0.9944, test_auc: 0.8578, lr: 0.1000
# epoch: 17, train_loss: 0.0016, train_auc: 0.9943, test_auc: 0.8540, lr: 0.1000
# epoch: 18, train_loss: 0.0016, train_auc: 0.9943, test_auc: 0.8553, lr: 0.1000
# epoch: 19, train_loss: 0.0018, train_auc: 0.9944, test_auc: 0.8565, lr: 0.1000

# %%
torch.save(model, "resnet_pneumonia.pt")

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (9,5)
x=np.arange(len(train_log))
plt.figure()
plt.plot(x, train_log, linestyle='-', label='Train Set', linewidth=3)
plt.plot(x, test_log,  linestyle='-', label='Test Set', linewidth=3)
plt.title('AUCMLoss ',fontsize=25)
plt.legend(fontsize=15)
plt.ylabel('AUROC', fontsize=25)
plt.xlabel('Epoch', fontsize=25)
# Out:
# Text(0.5, 0, 'Epoch')
